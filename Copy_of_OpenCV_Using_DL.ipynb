# %% [markdown]
# <a href="https://colab.research.google.com/github/rohit3171999/BitMarket/blob/master/Copy_of_OpenCV_Using_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import pandas as pd
import numpy as np

# %%
img=cv2.imread("/content/drive/MyDrive/AI/DATASET/blue-butterfly.jpg");
print(img);
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
print(type(img));
# Out:
# <class 'numpy.ndarray'>

# %%
# Get Shape of image
h, w, c= img.shape
print(h, w, c)
# Out:
# 1009 1276 3

# %%
img=cv2.imread("/content/drive/MyDrive/AI/DATASET/blue-butterfly.jpg", cv2.IMREAD_GRAYSCALE)
print(img);
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
from matplotlib import pyplot as plt
f=plt.figure(figsize=(8,8))
f.add_subplot(1,1,1).set_title('Read Image');
plt.imshow(img, cmap="gray");
plt.show()

# %%
cv2.imwrite("output.jpg", img);
